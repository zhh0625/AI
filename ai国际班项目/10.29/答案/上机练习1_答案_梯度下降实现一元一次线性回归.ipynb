# %%
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
####### >>>>>填写<<<<<   设置你想要的真实斜率和截距， 以及数据点(50-200) >>>>>填写<<<<< ############
true_w = 5
true_b = 3
num_samples = 200

############################################################################################


# 初始化随机数据
X = tf.random.normal(shape=[num_samples, 1]).numpy()
noise = tf.random.normal(shape=[num_samples, 1]).numpy()

####### >>>>>填写<<<<< 在下述函数尾端，添加噪音项, 注意删除下划线 >>>>>填写<<<<<  ################################
y = X * true_w + true_b + noise
#######################################

plt.scatter(X, y)

# %%
W = tf.Variable(tf.random.uniform([1]))  # 随机初始化参数
b = tf.Variable(tf.random.uniform([1]))

# >>>>>填写<<<<<  定义一个随机一元一次线性函数  y = W * x + b   >>>>>填写<<<<<  ##
# 思考 这里的x为什么是小写？ #
def random_line(x):
 
    y = W * x + b 
    return y

# %%
plt.scatter(X, y)
plt.plot(X, random_line(X), c='r')

# %%
def loss_fn( x, y):
    y_ = random_line(x)
    return tf.reduce_mean(tf.square(y_ - y))

# %%
### >>>>>填写<<<<< 通过改变epochs 的值，推荐起始10， 和learning rate 学习率 推荐0.1起始 观察梯度下降学习的线性函数w b的值，以及loss函数的变化>>>>>填写<<<<<  ######

EPOCHS = 50
LEARNING_RATE = 0.01
#######################################################################################################################################



for epoch in range(EPOCHS):  # 迭代次数
    with tf.GradientTape() as tape:  # 追踪梯度
        loss = loss_fn(X, y)  # 计算损失
        dW, db = tape.gradient(loss, [W, b])  # 计算梯度
        W.assign_sub(LEARNING_RATE * dW)  # 更新梯度
        b.assign_sub(LEARNING_RATE * db)
    # 输出计算过程
    print('Epoch [{}/{}], loss [{:.3f}], W is [{:.3f}], b is [{:.3f}]'.format(epoch, EPOCHS, loss,
                                                                     float(W.numpy()),
                                                                     float(b.numpy())))
# Out:
# Epoch [0/50], loss [4.344], W is [3.666], b is [2.257]
# Epoch [1/50], loss [4.185], W is [3.700], b is [2.275]
# Epoch [2/50], loss [4.035], W is [3.734], b is [2.293]
# Epoch [3/50], loss [3.892], W is [3.767], b is [2.310]
# Epoch [4/50], loss [3.755], W is [3.799], b is [2.327]
# Epoch [5/50], loss [3.626], W is [3.830], b is [2.343]
# Epoch [6/50], loss [3.503], W is [3.861], b is [2.359]
# Epoch [7/50], loss [3.385], W is [3.891], b is [2.375]
# Epoch [8/50], loss [3.274], W is [3.920], b is [2.390]
# Epoch [9/50], loss [3.168], W is [3.948], b is [2.405]
# Epoch [10/50], loss [3.067], W is [3.975], b is [2.419]
# Epoch [11/50], loss [2.971], W is [4.002], b is [2.433]
# Epoch [12/50], loss [2.880], W is [4.029], b is [2.447]
# Epoch [13/50], loss [2.793], W is [4.054], b is [2.461]
# Epoch [14/50], loss [2.710], W is [4.079], b is [2.474]
# Epoch [15/50], loss [2.632], W is [4.104], b is [2.486]
# Epoch [16/50], loss [2.557], W is [4.127], b is [2.499]
# Epoch [17/50], loss [2.486], W is [4.151], b is [2.511]
# Epoch [18/50], loss [2.418], W is [4.173], b is [2.523]
# Epoch [19/50], loss [2.354], W is [4.195], b is [2.534]
# Epoch [20/50], loss [2.292], W is [4.217], b is [2.545]
# Epoch [21/50], loss [2.234], W is [4.238], b is [2.556]
# Epoch [22/50], loss [2.179], W is [4.258], b is [2.567]
# Epoch [23/50], loss [2.126], W is [4.278], b is [2.577]
# Epoch [24/50], loss [2.076], W is [4.298], b is [2.588]
# Epoch [25/50], loss [2.028], W is [4.317], b is [2.598]
# Epoch [26/50], loss [1.983], W is [4.335], b is [2.607]
# Epoch [27/50], loss [1.940], W is [4.354], b is [2.617]
# Epoch [28/50], loss [1.899], W is [4.371], b is [2.626]
# Epoch [29/50], loss [1.860], W is [4.388], b is [2.635]
# Epoch [30/50], loss [1.823], W is [4.405], b is [2.643]
# Epoch [31/50], loss [1.787], W is [4.422], b is [2.652]
# Epoch [32/50], loss [1.754], W is [4.438], b is [2.660]
# Epoch [33/50], loss [1.722], W is [4.453], b is [2.668]
# Epoch [34/50], loss [1.691], W is [4.468], b is [2.676]
# Epoch [35/50], loss [1.663], W is [4.483], b is [2.684]
# Epoch [36/50], loss [1.635], W is [4.498], b is [2.691]
# Epoch [37/50], loss [1.609], W is [4.512], b is [2.698]
# Epoch [38/50], loss [1.584], W is [4.525], b is [2.706]
# Epoch [39/50], loss [1.560], W is [4.539], b is [2.713]
# Epoch [40/50], loss [1.538], W is [4.552], b is [2.719]
# Epoch [41/50], loss [1.516], W is [4.565], b is [2.726]
# Epoch [42/50], loss [1.496], W is [4.577], b is [2.732]
# Epoch [43/50], loss [1.477], W is [4.589], b is [2.739]
# Epoch [44/50], loss [1.458], W is [4.601], b is [2.745]
# Epoch [45/50], loss [1.441], W is [4.613], b is [2.751]
# Epoch [46/50], loss [1.424], W is [4.624], b is [2.756]
# Epoch [47/50], loss [1.408], W is [4.635], b is [2.762]
# Epoch [48/50], loss [1.393], W is [4.646], b is [2.768]
# Epoch [49/50], loss [1.379], W is [4.656], b is [2.773]

# %%
plt.scatter(X, y)
plt.plot(X, random_line(X), c='r')
